# %%
#reload source files automatically
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.datasets import load_files
from pandas import DataFrame
import pandas as pd
import numpy as np
from pandas import read_html, concat, DataFrame
import numpy as np
from bs4 import BeautifulSoup as bs

# %%
from wtrec.loader import load_from_directory
df = load_from_directory('data')

# %%
from wtrec.transformer import _BaselineSample, transform_for_baseline

# %%
s = _BaselineSample(df.iloc[20])

# %%
a = transform_for_baseline(df)

# %%
a
# Out:
#                                                    raw       label max_rows  \
# 0    b'<table width="100%" border="0" cellspacing="...      entity        6
# 1    b'<table cellpadding="2" cellspacing="2" borde...       other       10
# 2    b'<table> \n <tbody>\n  <tr> \n   <td valign="...      entity       20
# 3    b'<table> \n <tbody>\n  <tr> \n   <td width="1...  relational       17
# 4    b'<table width="100%" border="0" cellspacing="...      entity        6
# 5    b'<table> \n <tbody>\n  <tr> \n   <td width="2...      matrix        7
# 6    b'<table> \n <tbody> \n  <tr> \n   <td valign=...       other        4
# 7    b'<table class="navbox mw-collapsible mw-colla...       other        3
# 8    b'<table> \n <tbody>\n  <tr> \n   <td valign="...  relational       39
# 9    b'<table border="1"> \n <tbody>\n  <tr> \n   <...      entity        9
# 10   b'<table border="0" cellpadding="0" cellspacin...  relational       72
# ...
